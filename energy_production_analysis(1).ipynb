# %%
from google.colab import files 
uploaded = files.upload()
# Out:
#      <input type="file" id="files-07fd7d82-51ed-47ad-8027-b3ae0da8274a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-07fd7d82-51ed-47ad-8027-b3ae0da8274a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# %% [markdown]
# STEP 0

# %%
import io
energy = pd.read_excel(io.BytesIO(uploaded['Energy Indicators.xls']))

# %%
 energy = energy[16:243]

# %%
energy
# Out:
#      Unnamed: 0                          Unnamed: 1  \
# 16          NaN                                 NaN
# 17          NaN                         Afghanistan
# 18          NaN                             Albania
# 19          NaN                             Algeria
# 20          NaN                      American Samoa
# ..          ...                                 ...
# 238         NaN  Venezuela (Bolivarian Republic of)
# 239         NaN                            Viet Nam
# 240         NaN           Wallis and Futuna Islands
# 241         NaN                               Yemen
# 242         NaN                              Zambia
#
#                              Unnamed: 2  Unnamed: 3  Unnamed: 4 Unnamed: 5
# 16                                  NaN  Petajoules  Gigajoules          %
# 17                          Afghanistan         321          10   78.66928
# 18                              Albania         102          35        100
# ...

# %%
 energy = energy.drop(energy.columns[[0, 1]], axis=1)

# %%
energy
# Out:
#                              Unnamed: 2  Unnamed: 3  Unnamed: 4 Unnamed: 5
# 16                                  NaN  Petajoules  Gigajoules          %
# 17                          Afghanistan         321          10   78.66928
# 18                              Albania         102          35        100
# 19                              Algeria        1959          51    0.55101
# 20                       American Samoa         ...         ...   0.641026
# ..                                  ...         ...         ...        ...
# 238  Venezuela (Bolivarian Republic of)        2871          95   67.83452
# 239                            Viet Nam        2554          28   45.32152
# 240           Wallis and Futuna Islands           0          26          0
# 241                               Yemen         344          13          0
# 242                              Zambia         400          26   99.71467
#
# [227 rows x 4 columns]

# %%
energy.rename(columns={'Unnamed: 2': 'Country','Unnamed: 3':'Energy Supply','Unnamed: 4':'Energy Supply per Capita','Unnamed: 5':'% Renewable'}, inplace=True)

# %%
energy
# Out:
#                                 Country Energy Supply  \
# 16                                  NaN    Petajoules
# 17                          Afghanistan           321
# 18                              Albania           102
# 19                              Algeria          1959
# 20                       American Samoa           ...
# ..                                  ...           ...
# 238  Venezuela (Bolivarian Republic of)          2871
# 239                            Viet Nam          2554
# 240           Wallis and Futuna Islands             0
# 241                               Yemen           344
# 242                              Zambia           400
#
#     Energy Supply per Capita % Renewable
# 16                Gigajoules           %
# 17                        10    78.66928
# 18                        35         100
# 19                        51     0.55101
# 20                       ...    0.641026
# ..                       ...         ...
# ...

# %%
import numpy as np

# %%
  energy.replace('...', np.nan,inplace = True)

# %%
  energy.replace('np.nan', np.nan,inplace = True)

# %%
energy
# Out:
#                                 Country Energy Supply  \
# 16                                  NaN    Petajoules
# 17                          Afghanistan           321
# 18                              Albania           102
# 19                              Algeria          1959
# 20                       American Samoa           NaN
# ..                                  ...           ...
# 238  Venezuela (Bolivarian Republic of)          2871
# 239                            Viet Nam          2554
# 240           Wallis and Futuna Islands             0
# 241                               Yemen           344
# 242                              Zambia           400
#
#     Energy Supply per Capita % Renewable
# 16                Gigajoules           %
# 17                        10    78.66928
# 18                        35         100
# 19                        51     0.55101
# 20                       NaN    0.641026
# ..                       ...         ...
# ...

# %%
energy['Energy Supply'] *= 1000000

# %%
energy.rename(index={"Republic of Korea": "South Korea", "United States of America": "United States", "United Kingdom of Great Britain and Northern Ireland": "United Kingdom", "China, Hong Kong Special Administrative Region": "Hong Kong"})
# Out:
#                                 Country  \
# 16                                  NaN
# 17                          Afghanistan
# 18                              Albania
# 19                              Algeria
# 20                       American Samoa
# ..                                  ...
# 238  Venezuela (Bolivarian Republic of)
# 239                            Viet Nam
# 240           Wallis and Futuna Islands
# 241                               Yemen
# 242                              Zambia
#
#                                          Energy Supply  \
# 16   PetajoulesPetajoulesPetajoulesPetajoulesPetajo...
# 17                                           321000000
# 18                                           102000000
# 19                                          1959000000
# 20                                                 NaN
# ..                                                 ...
# 238                                         2871000000
# ...

# %%
energy.loc[:,"Country"]
# Out:
# 16                                    NaN
# 17                            Afghanistan
# 18                                Albania
# 19                                Algeria
# 20                         American Samoa
#                       ...
# 238    Venezuela (Bolivarian Republic of)
# 239                              Viet Nam
# 240             Wallis and Futuna Islands
# 241                                 Yemen
# 242                                Zambia
# Name: Country, Length: 227, dtype: object

# %%
energy['Country'] = energy['Country'].str.extract('(^[a-zA-Z]+)', expand=False)

# %%
energy
# Out:
#          Country                                      Energy Supply  \
# 16           NaN  PetajoulesPetajoulesPetajoulesPetajoulesPetajo...
# 17   Afghanistan                                          321000000
# 18       Albania                                          102000000
# 19       Algeria                                         1959000000
# 20      American                                                NaN
# ..           ...                                                ...
# 238    Venezuela                                         2871000000
# 239         Viet                                         2554000000
# 240       Wallis                                                  0
# 241        Yemen                                          344000000
# 242       Zambia                                          400000000
#
#     Energy Supply per Capita % Renewable
# 16                Gigajoules           %
# 17                        10    78.66928
# ...

# %% [markdown]
# STEP 1

# %%
from google.colab import files 
x = files.upload()
# Out:
#      <input type="file" id="files-8955ab96-ab76-4dd0-b63f-c40fc3bdf47a" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8955ab96-ab76-4dd0-b63f-c40fc3bdf47a">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
gdp=pd.read_csv(io.BytesIO(x['world_bank.csv']))

# %%
 gdp = gdp[5:269]

# %%
gdp.rename(index={"Korea, Rep.": "South Korea", "Iran, Islamic Rep.": "Iran", "Hong Kong SAR, China": "Hong Kong"})
# Out:
#           Data Source World Development Indicators  \
# 5             Andorra                          AND
# 6         Afghanistan                          AFG
# 7              Angola                          AGO
# 8             Albania                          ALB
# 9          Arab World                          ARB
# ..                ...                          ...
# 263       Yemen, Rep.                          YEM
# 264      South Africa                          ZAF
# 265  Congo, Dem. Rep.                          COD
# 266            Zambia                          ZMB
# 267          Zimbabwe                          ZWE
#
#                                    Unnamed: 2      Unnamed: 3    Unnamed: 4  \
# 5    GDP at market prices (constant 2010 US$)  NY.GDP.MKTP.KD           NaN
# 6    GDP at market prices (constant 2010 US$)  NY.GDP.MKTP.KD           NaN
# 7    GDP at market prices (constant 2010 US$)  NY.GDP.MKTP.KD           NaN
# ...

# %%
gdp =gdp.rename(columns={'Data Source': 'Country'}) #renaming country column to be used in indexing then to join the three datasets

# %%
gdp=gdp.rename(columns={'Unnamed: 2':'Indicator Name','Unnamed: 3':'Indicator Code','Unnamed: 50':'2006','Unnamed: 51':'2007','Unnamed: 52':'2008','Unnamed: 53':'2009','Unnamed: 54':'2010','Unnamed: 55':'2011','Unnamed: 56':'2012',
  'Unnamed: 57':'2013','Unnamed: 58':'2014','Unnamed: 59':'2015'})

# %% [markdown]
# STEP 2

# %%
y=files.upload()
# Out:
#      <input type="file" id="files-79d24aa3-338e-43d2-b135-6022e2f465ff" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-79d24aa3-338e-43d2-b135-6022e2f465ff">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
scimEn = pd.read_excel(io.BytesIO(y['scimagojr-3.xlsx']))

# %%
 scimEn=scimEn[scimEn['Rank']<=15]

# %%
scimEn
# Out:
#     Rank             Country  Documents  Citable documents  Citations  \
# 0      1               China     127050             126767     597237
# 1      2       United States      96661              94747     792274
# 2      3               Japan      30504              30287     223024
# 3      4      United Kingdom      20944              20357     206091
# 4      5  Russian Federation      18534              18301      34266
# 5      6              Canada      17899              17620     215003
# 6      7             Germany      17027              16831     140566
# 7      8               India      15005              14841     128763
# 8      9              France      13153              12973     130632
# 9     10         South Korea      11983              11923     114675
# 10    11               Italy      10964              10794     111850
# 11    12               Spain       9428               9330     123336
# ...

# %%
  scimEn.set_index('Country')
# Out:
#                     Rank  Documents  Citable documents  Citations  \
# Country
# China                  1     127050             126767     597237
# United States          2      96661              94747     792274
# Japan                  3      30504              30287     223024
# United Kingdom         4      20944              20357     206091
# Russian Federation     5      18534              18301      34266
# Canada                 6      17899              17620     215003
# Germany                7      17027              16831     140566
# India                  8      15005              14841     128763
# France                 9      13153              12973     130632
# South Korea           10      11983              11923     114675
# Italy                 11      10964              10794     111850
# Spain                 12       9428               9330     123336
# Iran                  13       8896               8819      57470
# ...

# %%
 gdp.set_index('Country')
# Out:
#                  World Development Indicators  \
# Country
# Andorra                                   AND
# Afghanistan                               AFG
# Angola                                    AGO
# Albania                                   ALB
# Arab World                                ARB
# ...                                       ...
# Yemen, Rep.                               YEM
# South Africa                              ZAF
# Congo, Dem. Rep.                          COD
# Zambia                                    ZMB
# Zimbabwe                                  ZWE
#
#                                             Indicator Name  Indicator Code  \
# Country
# Andorra           GDP at market prices (constant 2010 US$)  NY.GDP.MKTP.KD
# Afghanistan       GDP at market prices (constant 2010 US$)  NY.GDP.MKTP.KD
# Angola            GDP at market prices (constant 2010 US$)  NY.GDP.MKTP.KD
# Albania           GDP at market prices (constant 2010 US$)  NY.GDP.MKTP.KD
# ...

# %%
 energy.set_index('Country')
# Out:
#                                                  Energy Supply  \
# Country
# NaN          PetajoulesPetajoulesPetajoulesPetajoulesPetajo...
# Afghanistan                                          321000000
# Albania                                              102000000
# Algeria                                             1959000000
# American                                                   NaN
# ...                                                        ...
# Venezuela                                           2871000000
# Viet                                                2554000000
# Wallis                                                       0
# Yemen                                                344000000
# Zambia                                               400000000
#
#             Energy Supply per Capita % Renewable
# Country
# NaN                       Gigajoules           %
# Afghanistan                       10    78.66928
# ...

# %% [markdown]
# step 3

# %%
df = pd.merge(pd.merge(energy, gdp, on='Country'), scimEn, on='Country')
df.set_index('Country',inplace=True)

df = df[['Rank', 'Documents', 'Citable documents', 'Citations', 'Self-citations', 'Citations per document', 'H index', 'Energy Supply', 'Energy Supply per Capita', '% Renewable', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013', '2014', '2015']]
df = (df.loc[df['Rank'].isin([i for i in range(1, 16)])])
df.sort_values('Rank',inplace=True)

# %%
df
# Out:
#            Rank  Documents  Citable documents  Citations  Self-citations  \
# Country
# China         1     127050             126767     597237          411683
# China         1     127050             126767     597237          411683
# China         1     127050             126767     597237          411683
# Japan         3      30504              30287     223024           61554
# Canada        6      17899              17620     215003           40930
# Germany       7      17027              16831     140566           27426
# India         8      15005              14841     128763           37209
# France        9      13153              12973     130632           28601
# Italy        11      10964              10794     111850           26661
# Spain        12       9428               9330     123336           23964
# Australia    14       8831               8725      90765           15606
# Brazil       15       8668               8596      60702           14396
#
# ...

# %% [markdown]
# STEP 4

# %%
before_filter = pd.merge(scimEn , pd.merge(energy, gdp ,how= 'outer', on='Country'),how='outer' , on='Country')
before_filter
# Out:
#      Rank           Country  Documents  Citable documents  Citations  \
# 0     1.0             China   127050.0           126767.0   597237.0
# 1     1.0             China   127050.0           126767.0   597237.0
# 2     1.0             China   127050.0           126767.0   597237.0
# 3     2.0     United States    96661.0            94747.0   792274.0
# 4     3.0             Japan    30504.0            30287.0   223024.0
# ..    ...               ...        ...                ...        ...
# 343   NaN             World        NaN                NaN        NaN
# 344   NaN       Yemen, Rep.        NaN                NaN        NaN
# 345   NaN      South Africa        NaN                NaN        NaN
# 346   NaN  Congo, Dem. Rep.        NaN                NaN        NaN
# 347   NaN          Zimbabwe        NaN                NaN        NaN
#
#      Self-citations  Citations per document  H index Energy Supply  \
# 0          411683.0                    4.70    138.0  127191000000
# ...

# %%
len(before_filter)-len(df)
# Out:
# 336

# %% [markdown]
# step 5

# %%
avgGDP = df.iloc[:,10:].T.mean(skipna = True).sort_values(ascending = False)

# %%
def step_5():
    avgGDP = df.iloc[:,10:].T.mean(skipna = True).sort_values(ascending = False)
    return avgGDP

# %%
assert type(step_5()) == pd.Series

# %%
avgGDP
# Out:
# Country
# China        6.348609e+12
# China        6.348609e+12
# China        6.348609e+12
# Japan        5.542208e+12
# Germany      3.493025e+12
# France       2.681725e+12
# Brazil       2.189794e+12
# Italy        2.120175e+12
# India        1.769297e+12
# Canada       1.660647e+12
# Spain        1.418078e+12
# Australia    1.164043e+12
# dtype: float64

# %% [markdown]
# step 6

# %%
df["Energy Supply per Capita"].mean()
# Out:
# 130.41666666666666

# %% [markdown]
# step 7

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 12 entries, China to Brazil
# Data columns (total 20 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   Rank                      12 non-null     int64
#  1   Documents                 12 non-null     int64
#  2   Citable documents         12 non-null     int64
#  3   Citations                 12 non-null     int64
#  4   Self-citations            12 non-null     int64
#  5   Citations per document    12 non-null     float64
#  6   H index                   12 non-null     int64
#  7   Energy Supply             12 non-null     object
#  8   Energy Supply per Capita  12 non-null     object
#  9   % Renewable               12 non-null     object
#  10  2006                      12 non-null     float64
#  11  2007                      12 non-null     float64
#  12  2008                      12 non-null     float64
# ...

# %% [markdown]
# step 8

# %%
df.rename(columns={'% Renewable':'Renewable'},inplace=True)

# %%
df['Renewable']=df.Renewable.astype(float)

# %%
x=df["Renewable"].idxmax()

# %%
df["Renewable"].idxmax(),df["Renewable"].max()
# Out:
# ('Brazil', 69.64803)

# %% [markdown]
# step 9

# %%
 meann= df["Renewable"].mean()

HighRenew = df["Renewable"].apply(lambda x : 1 if x > meann else 0)
HighRenew
# Out:
# Country
# China        0
# China        0
# China        0
# Japan        0
# Canada       1
# Germany      0
# India        0
# France       0
# Italy        1
# Spain        1
# Australia    0
# Brazil       1
# Name: Renewable, dtype: int64

# %% [markdown]
# step 10

# %%
ContinentDict  = {'China':'Asia', 
                  'United States':'North America', 
                  'Japan':'Asia', 
                  'United Kingdom':'Europe', 
                  'Russian Federation':'Europe', 
                  'Canada':'North America', 
                  'Germany':'Europe', 
                  'India':'Asia',
                  'France':'Europe', 
                  'South Korea':'Asia', 
                  'Italy':'Europe', 
                  'Spain':'Europe', 
                  'Iran':'Asia',
                  'Australia':'Australia', 
                  'Brazil':'South America'}
groups = pd.DataFrame(columns = ['size', 'sum', 'mean', 'std'])
df['Estimate Population'] = df['Energy Supply'] /df['Energy Supply per Capita']
for group, frame in df.groupby(ContinentDict):
    groups.loc[group] = [len(frame), frame['Estimate Population'].sum(),frame['Estimate Population'].mean(),frame['Estimate Population'].std()]
groups
# Out:
#                size           sum          mean           std
# Asia            5.0  2.779486e+09  5.558971e+08  7.020810e+08
# Australia       1.0  2.331602e+07  2.331602e+07           NaN
# Europe          4.0  2.505587e+08  6.263967e+07  1.397102e+07
# North America   1.0  3.523986e+07  3.523986e+07           NaN
# South America   1.0  2.059153e+08  2.059153e+08           NaN
